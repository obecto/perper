# %%
import numpy as np
from gym import spaces

from Environments.BaseMarket import MarketEnv, TestEnv

# %%
class Order():
    def __init__(self, order_info):
        self.action_type = order_info['action_type']
        self.amount = order_info['amount']
        self.at_price = order_info['at_price']
        self.time_horizon = order_info['time_horizon']
        self.age = 0
        self.expired = False
        
    def update_state(self):
        if self.age >= self.time_horizon:
            self.expired = True          
        self.age += 1
    
    def is_expired(self):
        
        return self.expired
    
    def is_executable(self, price):
        
        if self.action_type == 'sell':
            if self.at_price <= price:
                return True
            else:
                return False
            
        if self.action_type == 'buy':
            if self.at_price >= price:
                return True
            else:
                return False

# %%
order = Order({'action_type':'buy',
               'amount':1,
               'at_price':100,
               'time_horizon':20})
order.is_executable(100)
# Out:
# True

# %%
class LimitMarket(MarketEnv):
    def __init__(self, env_config):
        self.state_orders_num = env_config['state_orders_num']
        self.max_horizon = env_config['max_horizon']
        super().__init__(env_config)
        
    def modify_high_low(self,):
        
#       Append boundaries for percent of money is cash, cash and money in stocks
        self.high = np.append(self.high, [101, 2000, 1000])
        self.low = np.append(self.low, [-1, -1, -1])
            
#       We add boundary values for a number of orders to keep track off
#       We add two slots for all the orders left, valid and expired      

        state_orders_lows = [-1]*(self.state_orders_num+2)
        state_orders_highs = [np.inf]*(self.state_orders_num+2)
            
        self.low = np.append(self.low, state_orders_lows)
        self.high = np.append(self.high, state_orders_highs)
    
    def reset(self):
        self.orders = []    
        self.state_orders = []
        self.last_market_beater = 0
        self.blocked_cash = 0
        self.blocked_stocks = 0
        state = super().reset()
        print('-'*30 + "Reset called" + '-'*30)
        
        return state
    
    def test(self):
        self.orders = []    
        self.state_orders = []
        self.last_market_beater = 0
        self.blocked_cash = 0
        self.blocked_stocks = 0
        state = super().test()
        print('-'*30 + "Test called" + '-'*30)

        return state
    
    def set_action_space(self,):
        self.action_space = spaces.Tuple((spaces.Discrete(7), spaces.Box(low = 0, high=1, shape=(1,)), spaces.Discrete(4)))
    
    def modify_state(self, state):
        not_liquid_assets = self.current_price * self.current_stocks
        percentage_in_cash = 100 * (self.current_money/(self.current_money + not_liquid_assets))
        state = np.append(state, [percentage_in_cash, self.current_money, not_liquid_assets])
        self.update_state_orders()
        state = np.append(state, self.state_orders)
        
        return state
    
    def extract_action_info(self, action):
        coeff_trade_dict = {0: 0.1,
                      1: 0.2,
                      2: 0.5,
                      3: 0.01,
                      4: 0.02,
                      5: 0.05}
        
        coeff_order_dict = {0: 0,
                            1: 0.0025,
                            2: 0.005,
                            3: 0.01}
        
        try:
            coeff_order = coeff_order_dict[action[2]]
            coeff_trade = coeff_trade_dict[action[0]]
        except:
            action_type = 'hold'
        
        if action[0] == 6:
            return {'action_type': action_type}
        if action[0] in [0, 1, 2]:
            action_type = 'buy'
            order_price = self.current_price * (1 - coeff_order)
            amount = (self.current_money - self.blocked_cash) * coeff_trade / order_price
        if action[0] in [3, 4, 5]:
            action_type = 'sell'
            order_price = self.current_price * (1 + coeff_order)
            amount = (self.current_stocks - self.blocked_stocks) * coeff_trade
        
        time_horizon = int(self.max_horizon * action[1])
            
        action_info = {'action_type': action_type,
                       'at_price': order_price,
                       'amount': amount,
                       'time_horizon': time_horizon}
#         print("Action type: {}   Order price: {:.2f}   Amount: {:.2f}   Time horizon: {}\
#         Current_price: {}".format(action_type, order_price, amount, time_horizon, self.current_price))
        return action_info
    
    def do_action(self, action_info):
        done = 0
        reward = 0
        
        self.update_order_states()
        action_type = action_info['action_type']
        
        if action_type == 'hold':
            pass
        elif action_type == 'sell' and self.current_stocks - self.blocked_stocks == 0:
            reward -= 1
            pass
        elif action_type == 'buy' and self.current_money - self.blocked_cash == 0:
            reward -= 1
            pass
        else:
            self.place_order(action_info)
        
        punishment = self.remove_expired_orders()
        print('Expired orders: {}'.format(punishment))
        print("Remaining orders after removing expired: {}".format(len(self.orders)))
        executed = self.execute_orders()
        print('Executed orders: {}'.format(executed))
        print("Remaining orders after executing: {}".format(len(self.orders)))
        
        new_market_beater = self.calculate_market_beater()
        market_beater_delta = new_market_beater - self.last_market_beater
        self.last_market_beater = new_market_beater
        
        self.tick += 1
        if self.tick == len(self.data)-1:
            done = 1
        self.current_price = self.data['price'][self.tick]
        next_state = self.data.iloc[self.tick].values
        next_state = self.modify_state(next_state)
#         next_state = super().normalize_state(next_state)
        
        reward += market_beater_delta - punishment + executed
        assets = self.current_money + self.current_price * self.current_stocks
        
        info = {'current_price': self.current_price,
                                          'assets': assets,
                                          'market_beater': self.calculate_market_beater()}
        print("Free money: {}".format(self.current_money - self.blocked_cash))
        print("Free stocks value: {}".format((self.current_stocks - self.blocked_stocks) * self.current_price))
        print('{}\n'.format(info))
        
        return next_state, reward, done, info
    
    def place_order(self, order_info):
        order = Order(order_info)
        self.orders.append(order)
        if order.action_type == 'buy':
            self.blocked_cash += order.amount * order.at_price
        if order.action_type == 'sell':
            self.blocked_stocks += order.amount
    
    def remove_expired_orders(self):
        punishment = 0
        for order in self.orders:
            if order.is_expired():
                punishment += 1
                if order.action_type == 'buy':
                    self.blocked_cash -= order.amount * order.at_price
                if order.action_type == 'sell':
                    self.blocked_stocks -= order.amount
                self.orders.remove(order)
        return punishment
    
    def execute_orders(self):
        executed = 0
        for order in self.orders:
            if order.is_executable(self.current_price):
                executed += 1 
                if order.action_type == 'sell':
                    super().sell(order.amount)
                    self.blocked_stocks -= order.amount
                if order.action_type == 'buy':
                    super().buy(order.amount)
                    self.blocked_cash -= order.amount * order.at_price
                self.orders.remove(order)
        return executed
    
    def update_order_states(self):
        for order in self.orders:
            order.update_state()
    
#   When there are not enough orders made yet fill the left slots with zeros
    def extend_with_zeros(self):
        assert self.state_orders_num >= len(self.orders)
        zeros_extension = np.zeros(self.state_orders_num - len(self.orders)+2)
        self.state_orders = np.append(self.state_orders, zeros_extension)

    def fill_main_slots(self):
        assert self.state_orders_num < len(self.orders)
        for trade in self.orders[::-1][:self.state_orders_num]:
            self.state_orders.append(trade.amount*trade.at_price)
    
    def update_state_orders(self, mode='volume'):                
#       Calculate the sums for the orders outside the main slots
        def get_buy_sell_sums(orders):
            sell_volumes = []
            buy_volumes = []
            for order in orders:
                if order.action_type == 'sell':
                    sell_volumes.append(order.amount*order.at_price)
                if order.action_type == 'buy':
                    buy_volumes.append(order.amount*order.at_price)
                    
            if not sell_volumes:
                sell_sum = 0
            else:
                sell_sum = sum(sell_volumes)
                
            if not buy_volumes:
                buy_sum = 0
            else:
                buy_sum = sum(buy_volumes)
            
            return sell_sum, buy_sum
        
#       Fill the main slots with respect to mode and then fill the two slots remaining
        self.state_orders = []
        orders_copy = self.orders
        
        if mode == 'time':
            pass
                
        if mode == 'volume':
#             try:
#                 order = orders_copy[0]
#                 print(order.amount, order.at_price)
#             except:
#                 pass
            orders_copy.sort(key=lambda x:x.amount*x.at_price)
            
#       If there are not enough orders made yet extend with zeroes
        if len(orders_copy) <= self.state_orders_num:
            for order in orders_copy[::-1]:
                self.state_orders = np.append(self.state_orders, order.amount*order.at_price)
            self.extend_with_zeros()
            
#       Fill main slots and calculate means for the two other slots
        else:
            self.fill_main_slots()
            orders_left = orders_copy[:-self.state_orders_num]
            sell_sum_left, buy_sum_left = get_buy_sell_sums(orders_left)
            sell_sum, buy_sum = get_buy_sell_sums(orders_copy)
            print("Blocked in orders: sell-{} buy-{}".format(sell_sum, buy_sum))
            self.state_orders = np.append(self.state_orders, [sell_sum_left, buy_sum_left])

        if len(self.state_orders) != self.state_orders_num + 2:
            print("The orders to include in the state have an incorrect format")

# %%
conf = {'data': 'Data/ground_truth/',
        'starting_money': 1000,
        'starting_stocks': 0,
        'episode_length': 10000,
        'commission': 0.0025,
        'state_orders_num': 10,
        'max_horizon' : 1000,
        'curiosity_reward' : 0
        }
Market = LimitMarket(conf)

# %%
Market.reset()
done = 0
while not done:
    a = np.random.randint(7)
    b = np.random.randint(4)
    action = [a, 1/100, b]
    action_info = Market.extract_action_info(action)
    next_state, reward, done, info = Market.do_action(action_info)
# Out:
# ------------------------------Reset called------------------------------
# Expired orders: 0
# Remaining orders after removing expired: 1
# Executed orders: 0
# Remaining orders after executing: 1
# Free money: 800.0
# Free stocks value: 0.0
# {'current_price': 116.44, 'assets': 1000.0, 'market_beater': -0.000171791788352607}
#
# Expired orders: 0
# Remaining orders after removing expired: 1
# Executed orders: 0
# Remaining orders after executing: 1
# Free money: 800.0
# Free stocks value: 0.0
# {'current_price': 116.42, 'assets': 1000.0, 'market_beater': -1.1368683772161603e-16}
#
# Expired orders: 0
# Remaining orders after removing expired: 1
# Executed orders: 0
# Remaining orders after executing: 1
# Free money: 800.0
# Free stocks value: 0.0
# {'current_price': 116.42, 'assets': 1000.0, 'market_beater': -1.1368683772161603e-16}
#
# Expired orders: 0
# Remaining orders after removing expired: 1
# Executed orders: 0
# Remaining orders after executing: 1
# Free money: 800.0
# Free stocks value: 0.0
# {'current_price': 116.38, 'assets': 1000.0, 'market_beater': 0.0003435835767049866}
#
# Expired orders: 0
# Remaining orders after removing expired: 1
# Executed orders: 0
# Remaining orders after executing: 1
# Free money: 800.0
# Free stocks value: 0.0
# {'current_price': 116.42, 'assets': 1000.0, 'market_beater': -1.1368683772161603e-16}
#
# Expired orders: 0
# Remaining orders after removing expired: 1
# Executed orders: 0
# Remaining orders after executing: 1
# Free money: 800.0
# Free stocks value: 0.0
# {'current_price': 116.41, 'assets': 1000.0, 'market_beater': 8.589589417624665e-05}
#
# Expired orders: 0
# Remaining orders after removing expired: 1
# Executed orders: 0
# Remaining orders after executing: 1
# Free money: 800.0
# Free stocks value: 0.0
# {'current_price': 116.38, 'assets': 1000.0, 'market_beater': 0.0003435835767049866}
#
# Expired orders: 0
# Remaining orders after removing expired: 1
# Executed orders: 0
# Remaining orders after executing: 1
# Free money: 800.0
# Free stocks value: 0.0
# {'current_price': 116.43, 'assets': 1000.0, 'market_beater': -8.589589417636035e-05}
#
# Expired orders: 0
# Remaining orders after removing expired: 2
# Executed orders: 0
# Remaining orders after executing: 2
# Free money: 400.0
# Free stocks value: 0.0
# {'current_price': 116.36, 'assets': 1000.0, 'market_beater': 0.0005153753650574799}
#
# Expired orders: 0
# Remaining orders after removing expired: 2
# Executed orders: 0
# Remaining orders after executing: 2
# Free money: 400.0
# Free stocks value: 0.0
# {'current_price': 116.39, 'assets': 1000.0, 'market_beater': 0.00025768768252873995}
#
# Expired orders: 0
# Remaining orders after removing expired: 2
# Executed orders: 0
# Remaining orders after executing: 2
# Free money: 400.0
# Free stocks value: 0.0
# {'current_price': 116.37, 'assets': 1000.0, 'market_beater': 0.0004294794708812333}
#
# Expired orders: 1
# Remaining orders after removing expired: 1
# Executed orders: 0
# Remaining orders after executing: 1
# Free money: 600.0
# Free stocks value: 0.0
# {'current_price': 116.37, 'assets': 1000.0, 'market_beater': 0.0004294794708812333}
#
# Expired orders: 0
# Remaining orders after removing expired: 2
# Executed orders: 0
# Remaining orders after executing: 2
# Free money: 480.0
# Free stocks value: 0.0
# {'current_price': 116.37, 'assets': 1000.0, 'market_beater': 0.0004294794708812333}
#
# Expired orders: 0
# Remaining orders after removing expired: 2
# Executed orders: 0
# Remaining orders after executing: 2
# Free money: 480.0
# Free stocks value: 0.0
# {'current_price': 116.37, 'assets': 1000.0, 'market_beater': 0.0004294794708812333}
#
# Expired orders: 0
# Remaining orders after removing expired: 2
# Executed orders: 0
# Remaining orders after executing: 2
# Free money: 480.0
# Free stocks value: 0.0
# {'current_price': 116.37, 'assets': 1000.0, 'market_beater': 0.0004294794708812333}
#
# Expired orders: 0
# Remaining orders after removing expired: 2
# Executed orders: 0
# Remaining orders after executing: 2
# Free money: 480.0
# Free stocks value: 0.0
# {'current_price': 116.34, 'assets': 1000.0, 'market_beater': 0.0006871671534099732}
#
# Expired orders: 0
# Remaining orders after removing expired: 3
# Executed orders: 0
# Remaining orders after executing: 3
# Free money: 432.0
# Free stocks value: 0.0
# {'current_price': 116.31, 'assets': 1000.0, 'market_beater': 0.0009448548359387132}
#
# Expired orders: 0
# Remaining orders after removing expired: 3
# Executed orders: 0
# Remaining orders after executing: 3
# Free money: 432.0
# Free stocks value: 0.0
# {'current_price': 116.3, 'assets': 1000.0, 'market_beater': 0.0010307507301150736}
#
# Expired orders: 0
# Remaining orders after removing expired: 3
# Executed orders: 0
# Remaining orders after executing: 3
# Free money: 432.0
# Free stocks value: 0.0
# {'current_price': 116.3, 'assets': 1000.0, 'market_beater': 0.0010307507301150736}
#
# Expired orders: 1
# Remaining orders after removing expired: 2
# Executed orders: 0
# Remaining orders after executing: 2
# Free money: 832.0
# Free stocks value: 0.0
# {'current_price': 116.31, 'assets': 1000.0, 'market_beater': 0.0009448548359387132}
#
# Expired orders: 0
# Remaining orders after removing expired: 2
# Executed orders: 0
# Remaining orders after executing: 2
# Free money: 832.0
# Free stocks value: 0.0
# {'current_price': 116.32, 'assets': 1000.0, 'market_beater': 0.0008589589417625803}
#
# Expired orders: 0
# Remaining orders after removing expired: 3
# Executed orders: 1
# Remaining orders after executing: 2
# Free money: 831.2847317744154
# Free stocks value: 0.7132960419390423
# {'current_price': 116.29, 'assets': 999.9980278163545, 'market_beater': 0.001114674440645672}
#
# Expired orders: 0
# Remaining orders after removing expired: 3
# Executed orders: 0
# Remaining orders after executing: 3
# Free money: 415.6423658872077
# Free stocks value: 0.7128666780819976
# {'current_price': 116.22, 'assets': 999.9975984524974, 'market_beater': 0.0017155163360225744}
#
# Expired orders: 1
# Remaining orders after removing expired: 3
# Executed orders: 0
# Remaining orders after executing: 3
# Free money: 327.82118294360384
# Free stocks value: 0.7124986519188163
# {'current_price': 116.16, 'assets': 999.9972304263342, 'market_beater': 0.002230523674916867}
#
# Expired orders: 0
# Remaining orders after removing expired: 4
# Executed orders: 0
# Remaining orders after executing: 4
# Free money: 327.82118294360384
# Free stocks value: 0.6771068025595569
# {'current_price': 116.2, 'assets': 999.9974757771097, 'market_beater': 0.001887185448987225}
#
# Expired orders: 0
# Remaining orders after removing expired: 5
# Executed orders: 1
# Remaining orders after executing: 4
# Free money: 327.2569468283825
# Free stocks value: 1.2407859814188376
# {'current_price': 116.28, 'assets': 999.9969433758251, 'market_beater': 0.0011994858942927066}
#
# Expired orders: 0
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 261.805557462706
# Free stocks value: 1.2406792746780895
# {'current_price': 116.27, 'assets': 999.9968336021997, 'market_beater': 0.0012852720148434854}
#
# Expired orders: 1
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 283.62500171643546
# Free stocks value: 1.2403591544558452
# {'current_price': 116.24, 'assets': 999.9965042813234, 'market_beater': 0.0015426303764960493}
#
# Expired orders: 0
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 283.62500171643546
# Free stocks value: 1.2407859814188376
# {'current_price': 116.28, 'assets': 999.9969433758251, 'market_beater': 0.0011994858942927066}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 1
# Remaining orders after executing: 5
# Free money: 283.13717061613204
# Free stocks value: 1.726951838980841
# {'current_price': 116.25, 'assets': 999.9952689324297, 'market_beater': 0.001455499133425974}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 226.50973649290563
# Free stocks value: 1.7276946139653486
# {'current_price': 116.3, 'assets': 999.9960270418376, 'market_beater': 0.0010267777719526522}
#
# Expired orders: 0
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 203.85876284361507
# Free stocks value: 1.7276946139653486
# {'current_price': 116.3, 'assets': 999.9960270418376, 'market_beater': 0.0010267777719526522}
#
# Expired orders: 0
# Remaining orders after removing expired: 8
# Executed orders: 0
# Remaining orders after executing: 8
# Free money: 203.85876284361507
# Free stocks value: 1.7099764594848976
# {'current_price': 116.27, 'assets': 999.9955721761928, 'market_beater': 0.0012840105888366224}
#
# Expired orders: 1
# Remaining orders after removing expired: 8
# Executed orders: 0
# Remaining orders after executing: 8
# Free money: 619.5011287308228
# Free stocks value: 1.6257350802819261
# {'current_price': 116.36, 'assets': 999.9969367731272, 'market_beater': 0.0005123121381847113}
#
# Expired orders: 1
# Remaining orders after removing expired: 8
# Executed orders: 1
# Remaining orders after executing: 7
# Free money: 826.2575108343942
# Free stocks value: 2.686949932680264
# {'current_price': 116.32, 'assets': 999.9933031618651, 'market_beater': 0.0008522621036277087}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 826.2575108343942
# Free stocks value: 2.723092061967649
# {'current_price': 116.34, 'assets': 999.9937889664461, 'market_beater': 0.0006809561198560913}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 826.2575108343942
# Free stocks value: 2.7237942517721794
# {'current_price': 116.37, 'assets': 999.9945176733175, 'market_beater': 0.00042399714419877907}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 478.5801447828736
# Free stocks value: 2.722155808894942
# {'current_price': 116.3, 'assets': 999.9928173572841, 'market_beater': 0.0010235680873992123}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 1
# Remaining orders after executing: 5
# Free money: 504.3491956755046
# Free stocks value: 3.13209318468242
# {'current_price': 116.28, 'assets': 999.9912322013873, 'market_beater': 0.0011937747198549004}
#
# Expired orders: 0
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 504.3491956755046
# Free stocks value: 3.13128511110536
# {'current_price': 116.25, 'assets': 999.9903976107433, 'market_beater': 0.0014506278117396507}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 504.3491956755046
# Free stocks value: 3.1015722456768846
# {'current_price': 116.31, 'assets': 999.9920667920314, 'market_beater': 0.0009369216279701504}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 560.976629798731
# Free stocks value: 3.0392794697685255
# {'current_price': 116.3, 'assets': 999.9917885951501, 'market_beater': 0.001022539325265143}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 583.6276034480215
# Free stocks value: 3.008627957385968
# {'current_price': 116.29, 'assets': 999.9915103982687, 'market_beater': 0.0011081570225599082}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 583.6276034480215
# Free stocks value: 2.8752247527557553
# {'current_price': 116.28, 'assets': 999.9912322013873, 'market_beater': 0.0011937747198549004}
#
# Expired orders: 1
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 583.6276034480215
# Free stocks value: 2.960730929202347
# {'current_price': 116.28, 'assets': 999.9912322013873, 'market_beater': 0.0011937747198549004}
#
# Expired orders: 0
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 583.6276034480215
# Free stocks value: 2.9602216875564573
# {'current_price': 116.26, 'assets': 999.9906758076247, 'market_beater': 0.0013650101144447716}
#
# Expired orders: 0
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 583.6276034480215
# Free stocks value: 2.9612401708482365
# {'current_price': 116.3, 'assets': 999.9917885951501, 'market_beater': 0.001022539325265143}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 466.90208275841724
# Free stocks value: 2.9612401708482365
# {'current_price': 116.3, 'assets': 999.9917885951501, 'market_beater': 0.001022539325265143}
#
# Expired orders: 1
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 880.0308381756143
# Free stocks value: 2.961749412494126
# {'current_price': 116.32, 'assets': 999.9923449889127, 'market_beater': 0.0008513039306752717}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 880.0308381756143
# Free stocks value: 2.811726823615039
# {'current_price': 116.24, 'assets': 999.9901194138621, 'market_beater': 0.0015362455090347565}
#
# Expired orders: 0
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 704.0246705404915
# Free stocks value: 2.811726823615039
# {'current_price': 116.24, 'assets': 999.9901194138621, 'market_beater': 0.0015362455090347565}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 633.6222034864422
# Free stocks value: 2.843770731228666
# {'current_price': 116.27, 'assets': 999.9909540045061, 'market_beater': 0.0012793924171498928}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 633.6222034864422
# Free stocks value: 2.763592306438336
# {'current_price': 116.27, 'assets': 999.9909540045061, 'market_beater': 0.0012793924171498928}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 633.6222034864422
# Free stocks value: 2.7670551098812295
# {'current_price': 116.3, 'assets': 999.9917885951501, 'market_beater': 0.001022539325265143}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 633.6222034864422
# Free stocks value: 2.862650544075399
# {'current_price': 116.32, 'assets': 999.9923449889127, 'market_beater': 0.0008513039306752717}
#
# Expired orders: 0
# Remaining orders after removing expired: 8
# Executed orders: 0
# Remaining orders after executing: 8
# Free money: 633.6222034864422
# Free stocks value: 2.8051563539011477
# {'current_price': 116.31, 'assets': 999.9920667920314, 'market_beater': 0.0009369216279701504}
#
# Expired orders: 0
# Remaining orders after removing expired: 9
# Executed orders: 0
# Remaining orders after executing: 9
# Free money: 506.89776278915383
# Free stocks value: 2.804915174608404
# {'current_price': 116.3, 'assets': 999.9917885951501, 'market_beater': 0.001022539325265143}
#
# Expired orders: 0
# Remaining orders after removing expired: 10
# Executed orders: 0
# Remaining orders after executing: 10
# Free money: 506.89776278915383
# Free stocks value: 2.749289582530013
# {'current_price': 116.32, 'assets': 999.9923449889127, 'market_beater': 0.0008513039306752717}
#
# Expired orders: 1
# Remaining orders after removing expired: 10
# Executed orders: 1
# Remaining orders after executing: 9
# Free money: 623.6781318059296
# Free stocks value: 2.694072162286662
# {'current_price': 116.31, 'assets': 999.9919340546664, 'market_beater': 0.0009367888906051576}
#
# Expired orders: 0
# Remaining orders after removing expired: 10
# Executed orders: 0
# Remaining orders after executing: 10
# Free money: 623.6781318059296
# Free stocks value: 2.558268318356762
# {'current_price': 116.26, 'assets': 999.9905667058305, 'market_beater': 0.0013649010126505344}
#
# Expired orders: 1
# Remaining orders after removing expired: 10
# Executed orders: 0
# Remaining orders after executing: 10
# Free money: 623.6781318059296
# Free stocks value: 2.579031314355062
# {'current_price': 116.29, 'assets': 999.991387115132, 'market_beater': 0.0011080337394232629}
#
# Expired orders: 1
# Remaining orders after removing expired: 10
# Executed orders: 0
# Remaining orders after executing: 10
# Free money: 737.3164862604596
# Free stocks value: 2.578144210970642
# {'current_price': 116.25, 'assets': 999.9902932360633, 'market_beater': 0.0014505234370595873}
#
# Expired orders: 1
# Remaining orders after removing expired: 10
# Executed orders: 1
# Remaining orders after executing: 9
# Free money: 804.5476996101625
# Free stocks value: 5.741469781055839
# {'current_price': 116.25, 'assets': 999.9823651018023, 'market_beater': 0.0014425953027986226}
#
# Expired orders: 1
# Remaining orders after removing expired: 9
# Executed orders: 0
# Remaining orders after executing: 9
# Free money: 804.5476996101625
# Free stocks value: 5.765330774950816
# {'current_price': 116.18, 'assets': 999.9785460152392, 'market_beater': 0.002040047475469237}
#
# Expired orders: 1
# Remaining orders after removing expired: 9
# Executed orders: 1
# Remaining orders after executing: 8
# Free money: 804.8352454825631
# Free stocks value: 5.505626379508153
# {'current_price': 116.2, 'assets': 999.9788668923574, 'market_beater': 0.0018685765642348997}
#
# Expired orders: 1
# Remaining orders after removing expired: 8
# Executed orders: 0
# Remaining orders after executing: 8
# Free money: 804.8352454825631
# Free stocks value: 5.505863633128068
# {'current_price': 116.2, 'assets': 999.9788668923574, 'market_beater': 0.0018685765642348997}
#
# Expired orders: 1
# Remaining orders after removing expired: 8
# Executed orders: 1
# Remaining orders after executing: 7
# Free money: 801.3720989873714
# Free stocks value: 9.018322245325642
# {'current_price': 116.21, 'assets': 999.97102708603, 'market_beater': 0.001774840863731356}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 1
# Remaining orders after executing: 6
# Free money: 928.5463285066455
# Free stocks value: 8.578464655733475
# {'current_price': 116.36, 'assets': 999.9815886668988, 'market_beater': 0.0004969640319562813}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 835.6916956559809
# Free stocks value: 8.632365725448384
# {'current_price': 116.33, 'assets': 999.9792508926689, 'market_beater': 0.0007523139402551351}
#
# Expired orders: 0
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 417.8458478279905
# Free stocks value: 8.636076017602363
# {'current_price': 116.38, 'assets': 999.983147183052, 'market_beater': 0.00032673075975696975}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 417.8458478279905
# Free stocks value: 8.683753716272012
# {'current_price': 116.37, 'assets': 999.9823679249754, 'market_beater': 0.00041184739585662554}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 417.8458478279905
# Free stocks value: 8.814817044666686
# {'current_price': 116.41, 'assets': 999.9854849572819, 'market_beater': 7.1380851458116e-05}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 271.2907370945883
# Free stocks value: 8.813302601398124
# {'current_price': 116.39, 'assets': 999.9839264411287, 'market_beater': 0.0002416141236574276}
#
# Expired orders: 0
# Remaining orders after removing expired: 7
# Executed orders: 1
# Remaining orders after executing: 6
# Free money: 271.0576494263224
# Free stocks value: 9.04580755049328
# {'current_price': 116.39, 'assets': 999.983343721958, 'market_beater': 0.00024103140448676185}
#
# Expired orders: 1
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 271.0576494263224
# Free stocks value: 9.163136462678777
# {'current_price': 116.42, 'assets': 999.9857414252924, 'market_beater': -1.4258574707696425e-05}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 1
# Remaining orders after executing: 5
# Free money: 271.24045399875286
# Free stocks value: 8.979873733425201
# {'current_price': 116.42, 'assets': 999.9852832684692, 'market_beater': -1.4716731530938887e-05}
#
# Expired orders: 1
# Remaining orders after removing expired: 4
# Executed orders: 0
# Remaining orders after executing: 4
# Free money: 271.24045399875286
# Free stocks value: 9.03503423455277
# {'current_price': 116.42, 'assets': 999.9852832684692, 'market_beater': -1.4716731530938887e-05}
#
# Expired orders: 0
# Remaining orders after removing expired: 5
# Executed orders: 1
# Remaining orders after executing: 4
# Free money: 270.7744851720929
# Free stocks value: 9.500654136237555
# {'current_price': 116.43, 'assets': 999.9849417640784, 'market_beater': -0.00010095413009798905}
#
# Expired orders: 0
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 243.69703665488362
# Free stocks value: 9.49820614496308
# {'current_price': 116.4, 'assets': 999.982471511051, 'market_beater': 0.00015426329940339658}
#
# Expired orders: 1
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 214.70315117810628
# Free stocks value: 9.499838139146064
# {'current_price': 116.42, 'assets': 999.9841183464025, 'market_beater': -1.588165359760296e-05}
#
# Expired orders: 1
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 589.6083687704754
# Free stocks value: 9.500654136237555
# {'current_price': 116.43, 'assets': 999.9849417640784, 'market_beater': -0.00010095413009798905}
#
# Expired orders: 1
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 589.6083687704754
# Free stocks value: 9.398653112078307
# {'current_price': 116.45, 'assets': 999.98658859943, 'market_beater': -0.0002710990830988749}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 1
# Remaining orders after executing: 5
# Free money: 589.7958719000615
# Free stocks value: 9.213052917174611
# {'current_price': 116.48, 'assets': 999.9885404939376, 'market_beater': -0.0005268348711200588}
#
# Expired orders: 1
# Remaining orders after removing expired: 5
# Executed orders: 1
# Remaining orders after executing: 4
# Free money: 798.8106960169055
# Free stocks value: 9.11622411067388
# {'current_price': 116.42, 'assets': 999.9835139706348, 'market_beater': -1.6486029365296417e-05}
#
# Expired orders: 0
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 798.8106960169055
# Free stocks value: 9.023511438048576
# {'current_price': 116.4, 'assets': 999.9819152383081, 'market_beater': 0.00015370702666052695}
#
# Expired orders: 0
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 798.8106960169055
# Free stocks value: 9.025061869567141
# {'current_price': 116.42, 'assets': 999.9835139706348, 'market_beater': -1.6486029365296417e-05}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 1
# Remaining orders after executing: 5
# Free money: 798.9007210090545
# Free stocks value: 8.935578714473161
# {'current_price': 116.43, 'assets': 999.9840799580938, 'market_beater': -0.0001018159360825166}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 1
# Remaining orders after executing: 5
# Free money: 795.4699011129406
# Free stocks value: 12.355698770919513
# {'current_price': 116.41, 'assets': 999.9733318176183, 'market_beater': 5.922771179450592e-05}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 1
# Remaining orders after executing: 5
# Free money: 796.0861415891403
# Free stocks value: 11.745980434096671
# {'current_price': 116.49, 'assets': 999.9800471602275, 'market_beater': -0.0006212240990063264}
#
# Expired orders: 1
# Remaining orders after removing expired: 5
# Executed orders: 1
# Remaining orders after executing: 4
# Free money: 819.7466180847634
# Free stocks value: 15.153109106234428
# {'current_price': 116.48, 'assets': 999.970179660375, 'market_beater': -0.0005451957046826693}
#
# Expired orders: 1
# Remaining orders after removing expired: 3
# Executed orders: 0
# Remaining orders after executing: 3
# Free money: 941.5951364122053
# Free stocks value: 15.146604509262316
# {'current_price': 116.43, 'assets': 999.9635543113827, 'market_beater': -0.00012234158279363783}
#
# Expired orders: 1
# Remaining orders after removing expired: 2
# Executed orders: 0
# Remaining orders after executing: 2
# Free money: 984.5357666478266
# Free stocks value: 15.146604509262316
# {'current_price': 116.43, 'assets': 999.9635543113827, 'market_beater': -0.00012234158279363783}
#
# Expired orders: 1
# Remaining orders after removing expired: 2
# Executed orders: 0
# Remaining orders after executing: 2
# Free money: 886.0821899830439
# Free stocks value: 15.33266587397831
# {'current_price': 116.4, 'assets': 999.9595791019873, 'market_beater': 0.00013137089033966732}
#
# Expired orders: 0
# Remaining orders after removing expired: 2
# Executed orders: 0
# Remaining orders after executing: 2
# Free money: 886.0821899830439
# Free stocks value: 15.333983113314561
# {'current_price': 116.41, 'assets': 999.9609041717857, 'market_beater': 4.680006596197472e-05}
#
# Expired orders: 0
# Remaining orders after removing expired: 3
# Executed orders: 0
# Remaining orders after executing: 3
# Free money: 886.0821899830439
# Free stocks value: 15.026012556498742
# {'current_price': 116.4, 'assets': 999.9595791019873, 'market_beater': 0.00013137089033966732}
#
# Expired orders: 1
# Remaining orders after removing expired: 3
# Executed orders: 0
# Remaining orders after executing: 3
# Free money: 886.0821899830439
# Free stocks value: 14.81282016418882
# {'current_price': 116.37, 'assets': 999.9556038925919, 'market_beater': 0.00038508336347308614}
#
# Expired orders: 0
# Remaining orders after removing expired: 4
# Executed orders: 1
# Remaining orders after executing: 3
# Free money: 882.2750137779093
# Free stocks value: 18.612077679341617
# {'current_price': 116.38, 'assets': 999.9477373652878, 'market_beater': 0.000291320941992808}
#
# Expired orders: 0
# Remaining orders after removing expired: 4
# Executed orders: 0
# Remaining orders after executing: 4
# Free money: 882.2750137779093
# Free stocks value: 18.23513432919376
# {'current_price': 116.35, 'assets': 999.9427831256618, 'market_beater': 0.0005440543848956167}
#
# Expired orders: 0
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 882.2750137779093
# Free stocks value: 18.05743776449724
# {'current_price': 116.38, 'assets': 999.9477373652878, 'market_beater': 0.000291320941992808}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 882.2750137779093
# Free stocks value: 17.691727326183784
# {'current_price': 116.35, 'assets': 999.9427831256618, 'market_beater': 0.0005440543848956167}
#
# Expired orders: 0
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 794.0475124001184
# Free stocks value: 17.676521716105416
# {'current_price': 116.25, 'assets': 999.9262689935749, 'market_beater': 0.0013864991945712292}
#
# Expired orders: 0
# Remaining orders after removing expired: 8
# Executed orders: 0
# Remaining orders after executing: 8
# Free money: 794.0475124001184
# Free stocks value: 17.324481431570987
# {'current_price': 116.26, 'assets': 999.9279204067836, 'market_beater': 0.0013022547136037018}
#
# Expired orders: 0
# Remaining orders after removing expired: 9
# Executed orders: 0
# Remaining orders after executing: 9
# Free money: 714.6427611601065
# Free stocks value: 17.33342233029707
# {'current_price': 116.32, 'assets': 999.9378288860357, 'market_beater': 0.0007967878277983119}
#
# Expired orders: 1
# Remaining orders after removing expired: 9
# Executed orders: 0
# Remaining orders after executing: 9
# Free money: 813.0963378248891
# Free stocks value: 16.44976350620266
# {'current_price': 116.2, 'assets': 999.9180119275316, 'market_beater': 0.0018077215994090922}
#
# Expired orders: 0
# Remaining orders after removing expired: 10
# Executed orders: 0
# Remaining orders after executing: 10
# Free money: 813.0963378248891
# Free stocks value: 16.119380906626276
# {'current_price': 116.19, 'assets': 999.916360514323, 'market_beater': 0.0018919660803768466}
#
# Expired orders: 1
# Remaining orders after removing expired: 10
# Executed orders: 0
# Remaining orders after executing: 10
# Free money: 813.0963378248891
# Free stocks value: 15.616823322720425
# {'current_price': 116.17, 'assets': 999.9130576879055, 'market_beater': 0.0020604550423119006}
#
# Expired orders: 1
# Remaining orders after removing expired: 9
# Executed orders: 0
# Remaining orders after executing: 9
# Free money: 813.0963378248891
# Free stocks value: 15.898938128811034
# {'current_price': 116.04, 'assets': 999.8915893161927, 'market_beater': 0.0031556332948904356}
#
# Expired orders: 0
# Remaining orders after removing expired: 10
# Executed orders: 1
# Remaining orders after executing: 9
# Free money: 812.39563432797
# Free stocks value: 16.61362381980898
# {'current_price': 116.15, 'assets': 999.9086656733352, 'market_beater': 0.0022278548160941224}
#
# Expired orders: 1
# Remaining orders after removing expired: 8
# Executed orders: 0
# Remaining orders after executing: 8
# Free money: 812.39563432797
# Free stocks value: 16.988054406867565
# {'current_price': 116.17, 'assets': 999.9120889671325, 'market_beater': 0.002059486321538884}
#
# Expired orders: 1
# Remaining orders after removing expired: 8
# Executed orders: 1
# Remaining orders after executing: 7
# Free money: 812.5650901706786
# Free stocks value: 17.010486853284515
# {'current_price': 116.24, 'assets': 999.9235434299577, 'market_beater': 0.0014696695251303709}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 812.5650901706786
# Free stocks value: 17.029526267951
# {'current_price': 116.23, 'assets': 999.9218464065027, 'market_beater': 0.0015538683958515093}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 494.5100464631302
# Free stocks value: 17.032456583062064
# {'current_price': 116.25, 'assets': 999.9252404534128, 'market_beater': 0.0013854706544091187}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 494.5100464631302
# Free stocks value: 17.215662451553552
# {'current_price': 116.25, 'assets': 999.9252404534128, 'market_beater': 0.0013854706544091187}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 1
# Remaining orders after executing: 6
# Free money: 571.7878727721179
# Free stocks value: 19.32396270159971
# {'current_price': 116.17, 'assets': 999.9048869223955, 'market_beater': 0.0020522842768018563}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 514.609085494906
# Free stocks value: 20.18082656292033
# {'current_price': 116.12, 'assets': 999.8954892857143, 'market_beater': 0.0024723661110019747}
#
# Expired orders: 1
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 514.609085494906
# Free stocks value: 20.509595330276653
# {'current_price': 116.12, 'assets': 999.8954892857143, 'market_beater': 0.0024723661110019747}
#
# Expired orders: 1
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 514.609085494906
# Free stocks value: 20.284357156330486
# {'current_price': 116.09, 'assets': 999.8898507037056, 'market_beater': 0.002724415211522114}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 463.14817694541546
# Free stocks value: 20.280862564693592
# {'current_price': 116.07, 'assets': 999.8860916490332, 'market_beater': 0.0028924479452023207}
#
# Expired orders: 0
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 416.83335925087397
# Free stocks value: 20.28959904378582
# {'current_price': 116.12, 'assets': 999.8954892857143, 'market_beater': 0.0024723661110019747}
#
# Expired orders: 0
# Remaining orders after removing expired: 8
# Executed orders: 0
# Remaining orders after executing: 8
# Free money: 208.41667962543704
# Free stocks value: 20.28260986051204
# {'current_price': 116.08, 'assets': 999.8879711763694, 'market_beater': 0.0028084315783621604}
#
# Expired orders: 0
# Remaining orders after removing expired: 9
# Executed orders: 0
# Remaining orders after executing: 9
# Free money: 104.20833981271846
# Free stocks value: 20.28260986051204
# {'current_price': 116.08, 'assets': 999.8879711763694, 'market_beater': 0.0028084315783621604}
#
# Expired orders: 1
# Remaining orders after removing expired: 9
# Executed orders: 0
# Remaining orders after executing: 9
# Free money: 104.20833981271846
# Free stocks value: 20.428320666688595
# {'current_price': 116.13, 'assets': 999.8973688130505, 'market_beater': 0.002388349744162042}
#
# Expired orders: 1
# Remaining orders after removing expired: 9
# Executed orders: 0
# Remaining orders after executing: 9
# Free money: 489.649216935514
# Free stocks value: 20.431838848151905
# {'current_price': 116.15, 'assets': 999.9011278677231, 'market_beater': 0.002220317010481949}
#
# Expired orders: 1
# Remaining orders after removing expired: 9
# Executed orders: 0
# Remaining orders after executing: 9
# Free money: 489.649216935514
# Free stocks value: 20.408235418144802
# {'current_price': 116.21, 'assets': 999.9124050317404, 'market_beater': 0.0017162188094417843}
#
# Expired orders: 0
# Remaining orders after removing expired: 10
# Executed orders: 0
# Remaining orders after executing: 10
# Free money: 489.649216935514
# Free stocks value: 20.00523379489759
# {'current_price': 116.24, 'assets': 999.9180436137491, 'market_beater': 0.0014641697089217587}
#
# Expired orders: 1
# Remaining orders after removing expired: 10
# Executed orders: 0
# Remaining orders after executing: 10
# Free money: 497.8630825191743
# Free stocks value: 20.003512766525695
# {'current_price': 116.23, 'assets': 999.9161640864128, 'market_beater': 0.0015481860757615778}
#
# Expired orders: 0
# Remaining orders after removing expired: 11
# Executed orders: 0
# Remaining orders after executing: 11
# Blocked in orders: sell-2.055649723834325 buy-480.20733533828275
# Free money: 497.8630825191743
# Free stocks value: 19.80177382077226
# {'current_price': 116.22, 'assets': 999.9142845590766, 'market_beater': 0.001632202442601738}
#
# Expired orders: 1
# Remaining orders after removing expired: 11
# Executed orders: 0
# Remaining orders after executing: 11
# Blocked in orders: sell-2.019904737604353 buy-480.20733533828275
# Free money: 497.8630825191743
# Free stocks value: 19.838048016955813
# {'current_price': 116.22, 'assets': 999.9142845590766, 'market_beater': 0.001632202442601738}
#
# Expired orders: 1
# Remaining orders after removing expired: 11
# Executed orders: 0
# Remaining orders after executing: 11
# Blocked in orders: sell-2.019904737604353 buy-478.5327350407096
# Free money: 499.53768281674746
# Free stocks value: 19.841461895465013
# {'current_price': 116.24, 'assets': 999.9180436137491, 'market_beater': 0.0014641697089217587}
#
# Expired orders: 1
# Remaining orders after removing expired: 11
# Executed orders: 0
# Remaining orders after executing: 11
# Blocked in orders: sell-2.019904737604353 buy-681.9867587545418
# Free money: 296.08365910291525
# Free stocks value: 19.843168834719613
# {'current_price': 116.25, 'assets': 999.9199231410853, 'market_beater': 0.0013801533420815986}
#
# Expired orders: 1
# Remaining orders after removing expired: 11
# Executed orders: 0
# Remaining orders after executing: 11
# Blocked in orders: sell-2.019904737604353 buy-532.7868109496878
# Free money: 445.28360690776924
# Free stocks value: 19.843168834719613
# {'current_price': 116.25, 'assets': 999.9199231410853, 'market_beater': 0.0013801533420815986}
#
# Expired orders: 1
# Remaining orders after removing expired: 11
# Executed orders: 0
# Remaining orders after executing: 11
# Blocked in orders: sell-2.019904737604353 buy-473.1068318277462
# Free money: 504.9635860297108
# Free stocks value: 19.838048016955813
# {'current_price': 116.22, 'assets': 999.9142845590766, 'market_beater': 0.001632202442601738}
#
# Expired orders: 1
# Remaining orders after removing expired: 11
# Executed orders: 0
# Remaining orders after executing: 11
# Blocked in orders: sell-1.8165715737527197 buy-523.6031904307173
# Free money: 454.4672274267398
# Free stocks value: 20.04629197361387
# {'current_price': 116.25, 'assets': 999.9199231410853, 'market_beater': 0.0013801533420815986}
#
# Expired orders: 1
# Remaining orders after removing expired: 11
# Executed orders: 0
# Remaining orders after executing: 11
# Blocked in orders: sell-2.8289093184202203 buy-502.7615224681736
# Free money: 475.30889538928346
# Free stocks value: 19.040700991728883
# {'current_price': 116.23, 'assets': 999.9161640864128, 'market_beater': 0.0015481860757615778}
#
# Expired orders: 1
# Remaining orders after removing expired: 11
# Executed orders: 1
# Remaining orders after executing: 10
# Free money: 475.6887573740684
# Free stocks value: 18.865969106311773
# {'current_price': 116.24, 'assets': 999.9170588148673, 'market_beater': 0.0014631849100400132}
#
# Expired orders: 1
# Remaining orders after removing expired: 10
# Executed orders: 0
# Remaining orders after executing: 10
# Free money: 380.55100589925473
# Free stocks value: 19.274239183758663
# {'current_price': 116.24, 'assets': 999.9170588148673, 'market_beater': 0.0014631849100400132}
#
# Expired orders: 1
# Remaining orders after removing expired: 10
# Executed orders: 1
# Remaining orders after executing: 9
# Free money: 427.8790082625444
# Free stocks value: 20.910663439751154
# {'current_price': 116.26, 'assets': 999.9169409841957, 'market_beater': 0.0012912752910157223}
#
# Expired orders: 1
# Remaining orders after removing expired: 9
# Executed orders: 0
# Remaining orders after executing: 9
# Free money: 213.9395041312722
# Free stocks value: 21.10893437595566
# {'current_price': 116.25, 'assets': 999.9149537503687, 'market_beater': 0.0013751839513649884}
#
# Expired orders: 1
# Remaining orders after removing expired: 9
# Executed orders: 0
# Remaining orders after executing: 9
# Free money: 213.9395041312722
# Free stocks value: 21.66777646833798
# {'current_price': 116.2, 'assets': 999.9050175812339, 'market_beater': 0.0017947272531114323}
#
# Expired orders: 1
# Remaining orders after removing expired: 9
# Executed orders: 0
# Remaining orders after executing: 9
# Free money: 263.7258123831897
# Free stocks value: 20.582616182989504
# {'current_price': 116.19, 'assets': 999.9030303474069, 'market_beater': 0.0018786359134608118}
#
# Expired orders: 1
# Remaining orders after removing expired: 9
# Executed orders: 0
# Remaining orders after executing: 9
# Free money: 460.7494913149254
# Free stocks value: 20.589702030715813
# {'current_price': 116.23, 'assets': 999.9109792827147, 'market_beater': 0.0015430012720635204}
#
# Expired orders: 1
# Remaining orders after removing expired: 8
# Executed orders: 0
# Remaining orders after executing: 8
# Free money: 519.9662231355085
# Free stocks value: 20.584387644921083
# {'current_price': 116.2, 'assets': 999.9050175812339, 'market_beater': 0.0017947272531114323}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 564.4945838262854
# Free stocks value: 20.584387644921083
# {'current_price': 116.2, 'assets': 999.9050175812339, 'market_beater': 0.0017947272531114323}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 1
# Remaining orders after executing: 6
# Free money: 615.4016009627727
# Free stocks value: 20.167491793943828
# {'current_price': 116.17, 'assets': 999.8981329480866, 'market_beater': 0.0020455303024930344}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 615.4016009627727
# Free stocks value: 20.76219172656108
# {'current_price': 116.15, 'assets': 999.89422933891, 'market_beater': 0.0022134184816688957}
#
# Expired orders: 0
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 615.4016009627727
# Free stocks value: 19.724082140233026
# {'current_price': 116.15, 'assets': 999.89422933891, 'market_beater': 0.0022134184816688957}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 710.5393524375863
# Free stocks value: 19.725780296250264
# {'current_price': 116.16, 'assets': 999.8961811434983, 'market_beater': 0.002129474392080965}
#
# Expired orders: 0
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 355.2696762187933
# Free stocks value: 19.73257292031922
# {'current_price': 116.2, 'assets': 999.9039883618517, 'market_beater': 0.0017936980337292425}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 569.2091803500655
# Free stocks value: 19.72238398421579
# {'current_price': 116.14, 'assets': 999.8922775343217, 'market_beater': 0.0022973625712568264}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 512.288262315059
# Free stocks value: 20.14589766328976
# {'current_price': 116.15, 'assets': 999.89422933891, 'market_beater': 0.0022134184816688957}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 461.059436083553
# Free stocks value: 21.243441970929986
# {'current_price': 116.23, 'assets': 999.9098437756167, 'market_beater': 0.0015418657649654505}
#
# Expired orders: 1
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 513.8045985601909
# Free stocks value: 21.23613114172206
# {'current_price': 116.19, 'assets': 999.9020365572633, 'market_beater': 0.0018776421233171732}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 256.90229928009546
# Free stocks value: 21.237958849024043
# {'current_price': 116.2, 'assets': 999.9039883618517, 'market_beater': 0.0017936980337292425}
#
# Expired orders: 0
# Remaining orders after removing expired: 7
# Executed orders: 1
# Remaining orders after executing: 6
# Free money: 257.9615424776905
# Free stocks value: 20.18126987238349
# {'current_price': 116.23, 'assets': 999.9069148746652, 'market_beater': 0.0015389368640139763}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 257.9615424776905
# Free stocks value: 20.174324584635958
# {'current_price': 116.19, 'assets': 999.8994731977723, 'market_beater': 0.0018750787638261953}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 1
# Remaining orders after executing: 5
# Free money: 256.8514575199588
# Free stocks value: 21.679454574470228
# {'current_price': 116.16, 'assets': 999.8908308227908, 'market_beater': 0.0021241240713734443}
#
# Expired orders: 1
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 231.16631176796295
# Free stocks value: 22.715697816568387
# {'current_price': 116.15, 'assets': 999.8888751019284, 'market_beater': 0.002208064244687307}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 115.58315588398148
# Free stocks value: 22.717653537430767
# {'current_price': 116.16, 'assets': 999.8908308227908, 'market_beater': 0.0021241240713734443}
#
# Expired orders: 1
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 470.85283210277464
# Free stocks value: 22.733299304329826
# {'current_price': 116.24, 'assets': 999.9064765896899, 'market_beater': 0.0014526026848625407}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 470.85283210277464
# Free stocks value: 22.496285493017734
# {'current_price': 116.19, 'assets': 999.896697985378, 'market_beater': 0.0018723035514318553}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 480.6884669275037
# Free stocks value: 22.496285493017734
# {'current_price': 116.19, 'assets': 999.896697985378, 'market_beater': 0.0018723035514318553}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 435.77959977350883
# Free stocks value: 22.498221656671493
# {'current_price': 116.2, 'assets': 999.8986537062403, 'market_beater': 0.0017883633781178789}
#
# Expired orders: 0
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 348.6236798188071
# Free stocks value: 22.498221656671493
# {'current_price': 116.2, 'assets': 999.8986537062403, 'market_beater': 0.0017883633781178789}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 605.5259790989026
# Free stocks value: 22.505966311286524
# {'current_price': 116.24, 'assets': 999.9064765896899, 'market_beater': 0.0014526026848625407}
#
# Expired orders: 0
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 605.5259790989026
# Free stocks value: 21.365953151953637
# {'current_price': 116.16, 'assets': 999.8908308227908, 'market_beater': 0.0021241240713734443}
#
# Expired orders: 0
# Remaining orders after removing expired: 8
# Executed orders: 0
# Remaining orders after executing: 8
# Free money: 605.5259790989026
# Free stocks value: 21.15957746809954
# {'current_price': 116.2, 'assets': 999.8986537062403, 'market_beater': 0.0017883633781178789}
#
# Expired orders: 0
# Remaining orders after removing expired: 9
# Executed orders: 0
# Remaining orders after executing: 9
# Free money: 544.9733811890123
# Free stocks value: 21.179608049179496
# {'current_price': 116.31, 'assets': 999.9201666357264, 'market_beater': 0.000865021471665159}
#
# Expired orders: 1
# Remaining orders after removing expired: 9
# Executed orders: 0
# Remaining orders after executing: 9
# Free money: 298.171836346502
# Free stocks value: 21.175966125346775
# {'current_price': 116.29, 'assets': 999.9162551940017, 'market_beater': 0.001032901818292885}
#
# Expired orders: 1
# Remaining orders after removing expired: 9
# Executed orders: 0
# Remaining orders after executing: 9
# Free money: 413.7549922304835
# Free stocks value: 20.75066226016181
# {'current_price': 116.28, 'assets': 999.9142994731394, 'market_beater': 0.001116841991606975}
#
# Expired orders: 0
# Remaining orders after removing expired: 10
# Executed orders: 0
# Remaining orders after executing: 10
# Free money: 413.7549922304835
# Free stocks value: 20.330402459485157
# {'current_price': 116.25, 'assets': 999.9084323105523, 'market_beater': 0.001368662511548564}
#
# Expired orders: 1
# Remaining orders after removing expired: 10
# Executed orders: 1
# Remaining orders after executing: 9
# Free money: 414.76897105315027
# Free stocks value: 19.54627778608844
# {'current_price': 116.28, 'assets': 999.9114958450582, 'market_beater': 0.001114038363525765}
#
# Expired orders: 1
# Remaining orders after removing expired: 8
# Executed orders: 0
# Remaining orders after executing: 8
# Free money: 461.8542542634277
# Free stocks value: 19.54627778608844
# {'current_price': 116.28, 'assets': 999.9114958450582, 'market_beater': 0.001114038363525765}
#
# Expired orders: 1
# Remaining orders after removing expired: 8
# Executed orders: 0
# ...
# Executed orders: 0
# Remaining orders after executing: 4
# Free money: 933.4145872824745
# Free stocks value: 47.00745044013489
# {'current_price': 104.67, 'assets': 987.4278895226216, 'market_beater': 0.08835556517972509}
#
# Expired orders: 0
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 840.0731285542271
# Free stocks value: 46.97601333751896
# {'current_price': 104.6, 'assets': 987.3917671269322, 'market_beater': 0.08892071404326964}
#
# Expired orders: 0
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 840.0731285542271
# Free stocks value: 46.97152232285954
# {'current_price': 104.59, 'assets': 987.3866067846909, 'market_beater': 0.08900144959520447}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 840.0731285542271
# Free stocks value: 46.501807099630945
# {'current_price': 104.59, 'assets': 987.3866067846909, 'market_beater': 0.08900144959520447}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 840.0731285542271
# Free stocks value: 46.47957657706682
# {'current_price': 104.54, 'assets': 987.3608050734842, 'market_beater': 0.08940512735487903}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 840.0731285542271
# Free stocks value: 47.07941512102982
# {'current_price': 104.61, 'assets': 987.3969274691736, 'market_beater': 0.08883997849133471}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 840.0731285542271
# Free stocks value: 48.63347201121564
# {'current_price': 104.53, 'assets': 987.3556447312428, 'market_beater': 0.08948586290681397}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 840.0731285542271
# Free stocks value: 48.62881942611937
# {'current_price': 104.52, 'assets': 987.3504843890015, 'market_beater': 0.0895665984587489}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 840.0731285542271
# Free stocks value: 47.213182978885015
# {'current_price': 104.64, 'assets': 987.4124084958976, 'market_beater': 0.0885977718355299}
#
# Expired orders: 0
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 672.0585028433817
# Free stocks value: 47.21769494209018
# {'current_price': 104.65, 'assets': 987.417568838139, 'market_beater': 0.08851703628359497}
#
# Expired orders: 0
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 672.0585028433817
# Free stocks value: 47.186111199654
# {'current_price': 104.58, 'assets': 987.3814464424496, 'market_beater': 0.08908218514713952}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 672.0585028433817
# Free stocks value: 47.30327739012988
# {'current_price': 104.59, 'assets': 987.3866067846909, 'market_beater': 0.08900144959520447}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 765.3999615716291
# Free stocks value: 46.85710965759939
# {'current_price': 104.65, 'assets': 987.417568838139, 'market_beater': 0.08851703628359497}
#
# Expired orders: 0
# Remaining orders after removing expired: 8
# Executed orders: 0
# Remaining orders after executing: 8
# Free money: 382.69998078581466
# Free stocks value: 46.83919963001884
# {'current_price': 104.61, 'assets': 987.3969274691736, 'market_beater': 0.08883997849133471}
#
# Expired orders: 1
# Remaining orders after removing expired: 8
# Executed orders: 1
# Remaining orders after executing: 7
# Free money: 383.63442281843356
# Free stocks value: 46.367787814036426
# {'current_price': 104.6, 'assets': 987.3895147170887, 'market_beater': 0.0889184616334261}
#
# Expired orders: 0
# Remaining orders after removing expired: 8
# Executed orders: 1
# Remaining orders after executing: 7
# Free money: 384.5594601853236
# Free stocks value: 45.453464686452946
# {'current_price': 104.63, 'assets': 987.4021427319941, 'market_beater': 0.08867340196580266}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 384.5594601853236
# Free stocks value: 45.01819488073985
# {'current_price': 104.65, 'assets': 987.4121070015248, 'market_beater': 0.08851157444698073}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 384.5594601853236
# Free stocks value: 45.977710404015
# {'current_price': 104.69, 'assets': 987.4320355405863, 'market_beater': 0.08818791940933739}
#
# Expired orders: 0
# Remaining orders after removing expired: 7
# Executed orders: 1
# Remaining orders after executing: 6
# Free money: 385.4767155078837
# Free stocks value: 45.0581561959347
# {'current_price': 104.69, 'assets': 987.4297366550661, 'market_beater': 0.0881856205238172}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 308.3813724063069
# Free stocks value: 47.48901527541742
# {'current_price': 104.68, 'assets': 987.424842356217, 'market_beater': 0.08826662211914424}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 1
# Remaining orders after executing: 5
# Free money: 477.3434039718969
# Free stocks value: 46.5303432551651
# {'current_price': 104.66, 'assets': 987.4128607713214, 'market_beater': 0.08842643232260128}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 1
# Remaining orders after executing: 5
# Free money: 475.06295583520716
# Free stocks value: 48.819079882712664
# {'current_price': 104.69, 'assets': 987.4222223912611, 'market_beater': 0.08817810626001221}
#
# Expired orders: 1
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 427.5566602516864
# Free stocks value: 51.19553342813854
# {'current_price': 104.72, 'assets': 987.4372851315425, 'market_beater': 0.0879354813177647}
#
# Expired orders: 1
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 427.5566602516864
# Free stocks value: 51.17673938807687
# {'current_price': 104.76, 'assets': 987.457368785251, 'market_beater': 0.08761198139476813}
#
# Expired orders: 1
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 767.5009750123323
# Free stocks value: 51.22070565902882
# {'current_price': 104.85, 'assets': 987.5025570060952, 'market_beater': 0.08688410656802613}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 1
# Remaining orders after executing: 5
# Free money: 768.52282809023
# Free stocks value: 50.1915041074557
# {'current_price': 104.84, 'assets': 987.4950727602095, 'market_beater': 0.08696251821631665}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 768.52282809023
# Free stocks value: 49.69432863038976
# {'current_price': 104.85, 'assets': 987.4999959708123, 'market_beater': 0.08688154553274319}
#
# Expired orders: 1
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 768.52282809023
# Free stocks value: 50.61978872092756
# {'current_price': 104.88, 'assets': 987.5147656026206, 'market_beater': 0.08663862748202279}
#
# Expired orders: 0
# Remaining orders after removing expired: 5
# Executed orders: 0
# Remaining orders after executing: 5
# Free money: 768.52282809023
# Free stocks value: 50.62944161732744
# {'current_price': 104.9, 'assets': 987.5246120238262, 'market_beater': 0.08647668211487575}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 768.52282809023
# Free stocks value: 50.11836901743622
# {'current_price': 104.89, 'assets': 987.5196888132234, 'market_beater': 0.08655765479844922}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 768.7658883827837
# Free stocks value: 50.13270356859003
# {'current_price': 104.92, 'assets': 987.5344584450319, 'market_beater': 0.08631473674772895}
#
# Expired orders: 0
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 384.38294419139186
# Free stocks value: 50.13270356859003
# {'current_price': 104.92, 'assets': 987.5344584450319, 'market_beater': 0.08631473674772895}
#
# Expired orders: 0
# Remaining orders after removing expired: 8
# Executed orders: 1
# Remaining orders after executing: 7
# Free money: 382.5511535690539
# Free stocks value: 51.954962377857214
# {'current_price': 104.91, 'assets': 987.5247816050762, 'market_beater': 0.08639095580194953}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 353.5472184387638
# Free stocks value: 51.959914714372125
# {'current_price': 104.92, 'assets': 987.5298789684759, 'market_beater': 0.08631015727117301}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 1
# Remaining orders after executing: 6
# Free money: 353.2102500643464
# Free stocks value: 52.79890724063739
# {'current_price': 104.9, 'assets': 987.5187777479318, 'market_beater': 0.0864708478389814}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 219.36079105734188
# Free stocks value: 52.79890724063739
# {'current_price': 104.9, 'assets': 987.5187777479318, 'market_beater': 0.0864708478389814}
#
# Expired orders: 0
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 175.48863284587355
# Free stocks value: 52.778774196884996
# {'current_price': 104.86, 'assets': 987.4982601487158, 'market_beater': 0.08679391381647042}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 87.74431642293678
# Free stocks value: 53.31127179865953
# {'current_price': 104.92, 'assets': 987.5290365475399, 'market_beater': 0.086309314850237}
#
# Expired orders: 0
# Remaining orders after removing expired: 8
# Executed orders: 1
# Remaining orders after executing: 7
# Free money: 87.5770569558706
# Free stocks value: 53.46282200579701
# {'current_price': 104.89, 'assets': 987.5131824941652, 'market_beater': 0.08655114847939104}
#
# Expired orders: 0
# Remaining orders after removing expired: 8
# Executed orders: 0
# Remaining orders after executing: 8
# Free money: 87.5770569558706
# Free stocks value: 52.493467492586745
# {'current_price': 105.09, 'assets': 987.6160885255457, 'market_beater': 0.08493613662724636}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 87.5770569558706
# Free stocks value: 53.000678933918
# {'current_price': 105.09, 'assets': 987.6160885255457, 'market_beater': 0.08493613662724636}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 164.4293397648936
# Free stocks value: 51.975262810514806
# {'current_price': 105.16, 'assets': 987.6521056365289, 'market_beater': 0.08437088247899578}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 1
# Remaining orders after executing: 6
# Free money: 467.66694289188126
# Free stocks value: 51.95549283607187
# {'current_price': 105.12, 'assets': 987.6292521711193, 'market_beater': 0.08469161259029123}
#
# Expired orders: 0
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 467.66694289188126
# Free stocks value: 49.36241356319847
# {'current_price': 105.13, 'assets': 987.6342955319466, 'market_beater': 0.08461076005694224}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 450.64378502731574
# Free stocks value: 49.36241356319847
# {'current_price': 105.13, 'assets': 987.6342955319466, 'market_beater': 0.08461076005694224}
#
# Expired orders: 0
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 450.64378502731574
# Free stocks value: 49.35771819426827
# {'current_price': 105.12, 'assets': 987.6292521711193, 'market_beater': 0.08469161259029123}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 1
# Remaining orders after executing: 6
# Free money: 626.8202154390292
# Free stocks value: 49.780605029748614
# {'current_price': 105.11, 'assets': 987.6230963942428, 'market_beater': 0.08477135270759095}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 608.0103521065947
# Free stocks value: 49.780605029748614
# {'current_price': 105.11, 'assets': 987.6230963942428, 'market_beater': 0.08477135270759095}
#
# Expired orders: 1
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 634.953633318872
# Free stocks value: 49.75692478760717
# {'current_price': 105.06, 'assets': 987.597676192616, 'market_beater': 0.08517541197684533}
#
# Expired orders: 0
# Remaining orders after removing expired: 6
# Executed orders: 0
# Remaining orders after executing: 6
# Free money: 634.953633318872
# Free stocks value: 49.77113293289204
# {'current_price': 105.09, 'assets': 987.6129283135921, 'market_beater': 0.08493297641529274}
#
# Expired orders: 0
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 507.9629066550976
# Free stocks value: 49.75692478760717
# {'current_price': 105.06, 'assets': 987.597676192616, 'market_beater': 0.08517541197684533}
#
# Expired orders: 0
# Remaining orders after removing expired: 8
# Executed orders: 0
# Remaining orders after executing: 8
# Free money: 406.37032532407807
# Free stocks value: 49.69535615803941
# {'current_price': 104.93, 'assets': 987.5315836683861, 'market_beater': 0.08622596607690684}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 406.37032532407807
# Free stocks value: 50.7489189456082
# {'current_price': 104.92, 'assets': 987.5264996280608, 'market_beater': 0.0863067779307579}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 0
# Remaining orders after executing: 7
# Free money: 488.58499520652487
# Free stocks value: 49.69127897070859
# {'current_price': 104.83, 'assets': 987.4807432651324, 'market_beater': 0.08703408461541585}
#
# Expired orders: 1
# Remaining orders after removing expired: 7
# Executed orders: 2
# Remaining orders after executing: 5
# Free money: 551.6605162727694
# Free stocks value: 51.85966137920099
# {'current_price': 104.78, 'assets': 987.451533478334, 'market_beater': 0.08743435429949864}
#
# Expired orders: 1
# Remaining orders after removing expired: 4
# Executed orders: 1
# Remaining orders after executing: 3
# Free money: 745.8170668091466
# Free stocks value: 52.82161553007041
# {'current_price': 104.77, 'assets': 987.4439715178719, 'market_beater': 0.08751268823321288}
#
# Expired orders: 0
# Remaining orders after removing expired: 4
# Executed orders: 1
# Remaining orders after executing: 3
# Free money: 746.343962424059
# Free stocks value: 52.318355659667475
# {'current_price': 104.82, 'assets': 987.4680909539458, 'market_beater': 0.08710732819840553}
#
# Expired orders: 0
# Remaining orders after removing expired: 4
# Executed orders: 1
# Remaining orders after executing: 3
# Free money: 748.9533404125849
# Free stocks value: 49.69769618255353
# {'current_price': 104.81, 'assets': 987.4567127270449, 'market_beater': 0.08718184586568077}
